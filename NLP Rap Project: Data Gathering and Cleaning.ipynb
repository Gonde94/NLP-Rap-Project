# %% [markdown]
# # NLP RAP PROJECT

# %% [markdown]
# ### Why do I like the Wu-Tang Clan more than other rap artists?

# %% [markdown]
# ### Inspired by adashofdata: https://github.com/adashofdata/nlp-in-python-tutorial
# ### and this article: https://pudding.cool/projects/vocabulary/index.html

# %% [markdown]
# ## DATA GATHERING

# %%
from bs4 import BeautifulSoup
import requests
import pickle

# %%
#add artists to UrlList

urlList = ["https://genius.com/artists/Wu-tang-clan",
           "https://genius.com/artists/A-tribe-called-quest",
           "https://genius.com/artists/Nwa",
           "https://genius.com/artists/Outkast",
           "https://genius.com/artists/Nas",
           "https://genius.com/artists/The-notorious-big",
           "https://genius.com/artists/2pac",
           "https://genius.com/artists/Logic",
           "https://genius.com/artists/Jay-z-and-kanye-west",
           "https://genius.com/artists/Tyler-the-creator",
           "https://genius.com/artists/Immortal-technique",
           "https://genius.com/artists/Kendrick-lamar"]

artistnames = ['Wu-Tang Clan','A Tribe Called Quest','N.W.A.','Outkast','Nas','The Notorious B.I.G.',
               '2pac','Logic','Jay-z and Kanye West','Tyler the Creator','Immortal Technique', 'Kendrick Lamar']

# %%
#Grab top 10 songs

songList = []

for e in urlList:
    page = requests.get(e)
    soup = BeautifulSoup(page.content, "html.parser")
    
    songLink = soup.find("div", class_="mini_card_grid")
    
    for link in songLink.find_all('a'):
        URL = link.get('href')
        print(URL)
        songList.append(URL)
# Out:
# https://genius.com/Wu-tang-clan-cream-lyrics
# https://genius.com/Wu-tang-clan-protect-ya-neck-lyrics
# https://genius.com/Wu-tang-clan-da-mystery-of-chessboxin-lyrics
# https://genius.com/Wu-tang-clan-method-man-lyrics
# https://genius.com/Wu-tang-clan-triumph-lyrics
# https://genius.com/Wu-tang-clan-bring-da-ruckus-lyrics
# https://genius.com/Wu-tang-clan-wu-tang-clan-aint-nuthing-ta-fuck-wit-lyrics
# https://genius.com/Wu-tang-clan-wu-tang-7th-chamber-lyrics
# https://genius.com/Wu-tang-clan-shame-on-a-nigga-lyrics
# https://genius.com/Wu-tang-clan-can-it-be-all-so-simple-intermission-lyrics
# https://genius.com/A-tribe-called-quest-we-the-people-lyrics
# https://genius.com/A-tribe-called-quest-electric-relaxation-lyrics
# https://genius.com/A-tribe-called-quest-scenario-lyrics
# https://genius.com/A-tribe-called-quest-can-i-kick-it-lyrics
# https://genius.com/A-tribe-called-quest-check-the-rhime-lyrics
# https://genius.com/A-tribe-called-quest-buggin-out-lyrics
# https://genius.com/A-tribe-called-quest-bonita-applebum-lyrics
# https://genius.com/A-tribe-called-quest-jazz-weve-got-lyrics
# https://genius.com/A-tribe-called-quest-the-space-program-lyrics
# https://genius.com/A-tribe-called-quest-award-tour-lyrics
# https://genius.com/Nwa-fuck-tha-police-lyrics
# https://genius.com/Nwa-straight-outta-compton-lyrics
# https://genius.com/Nwa-gangsta-gangsta-lyrics
# https://genius.com/Nwa-express-yourself-lyrics
# https://genius.com/Nwa-dope-man-lyrics
# https://genius.com/Nwa-chin-check-lyrics
songList.insert(117, 'https://genius.com/Kendrick-lamar-king-kunta-lyrics')
songList.insert(118, 'https://genius.com/Kendrick-lamar-love-lyrics')
songList.insert(119, 'https://genius.com/Kendrick-lamar-backseat-freestyle-lyrics')

# %%
songList
# Out:
# ['https://genius.com/Wu-tang-clan-cream-lyrics',
#  'https://genius.com/Wu-tang-clan-protect-ya-neck-lyrics',
#  'https://genius.com/Wu-tang-clan-da-mystery-of-chessboxin-lyrics',
#  'https://genius.com/Wu-tang-clan-method-man-lyrics',
#  'https://genius.com/Wu-tang-clan-triumph-lyrics',
#  'https://genius.com/Wu-tang-clan-bring-da-ruckus-lyrics',
#  'https://genius.com/Wu-tang-clan-wu-tang-clan-aint-nuthing-ta-fuck-wit-lyrics',
#  'https://genius.com/Wu-tang-clan-wu-tang-7th-chamber-lyrics',
#  'https://genius.com/Wu-tang-clan-shame-on-a-nigga-lyrics',
#  'https://genius.com/Wu-tang-clan-can-it-be-all-so-simple-intermission-lyrics',
#  'https://genius.com/A-tribe-called-quest-we-the-people-lyrics',
#  'https://genius.com/A-tribe-called-quest-electric-relaxation-lyrics',
#  'https://genius.com/A-tribe-called-quest-scenario-lyrics',
#  'https://genius.com/A-tribe-called-quest-can-i-kick-it-lyrics',
#  'https://genius.com/A-tribe-called-quest-check-the-rhime-lyrics',
#  'https://genius.com/A-tribe-called-quest-buggin-out-lyrics',
#  'https://genius.com/A-tribe-called-quest-bonita-applebum-lyrics',
#  'https://genius.com/A-tribe-called-quest-jazz-weve-got-lyrics',
#  'https://genius.com/A-tribe-called-quest-the-space-program-lyrics',
#  'https://genius.com/A-tribe-called-quest-award-tour-lyrics',
#  'https://genius.com/Nwa-fuck-tha-police-lyrics',
#  'https://genius.com/Nwa-straight-outta-compton-lyrics',
#  'https://genius.com/Nwa-gangsta-gangsta-lyrics',
#  'https://genius.com/Nwa-express-yourself-lyrics',
#  'https://genius.com/Nwa-dope-man-lyrics',
#  'https://genius.com/Nwa-chin-check-lyrics',
#  'https://genius.com/Nwa-a-bitch-iz-a-bitch-lyrics',
#  'https://genius.com/Nwa-real-niggaz-lyrics',
#  'https://genius.com/Nwa-appetite-for-destruction-lyrics',
#  'https://genius.com/Nwa-100-miles-and-runnin-lyrics',
#  'https://genius.com/Outkast-hey-ya-lyrics',
#  'https://genius.com/Outkast-ms-jackson-lyrics',
#  'https://genius.com/Outkast-roses-lyrics',
#  'https://genius.com/Outkast-aquemini-lyrics',
#  'https://genius.com/Outkast-atliens-lyrics',
#  'https://genius.com/Outkast-bob-lyrics',
#  'https://genius.com/Outkast-so-fresh-so-clean-lyrics',
#  'https://genius.com/Outkast-spottieottiedopaliscious-lyrics',
#  'https://genius.com/Outkast-elevators-me-and-you-lyrics',
#  'https://genius.com/Outkast-rosa-parks-lyrics',
#  'https://genius.com/Nas-ny-state-of-mind-lyrics',
#  'https://genius.com/Nas-ether-lyrics',
#  'https://genius.com/Nas-lifes-a-bitch-lyrics',
#  'https://genius.com/Tyler-the-creator-see-you-again-lyrics',
#  'https://genius.com/Tyler-the-creator-ifhy-lyrics',
#  'https://genius.com/Tyler-the-creator-she-lyrics',
#  'https://genius.com/Tyler-the-creator-new-magic-wand-lyrics',
#  'https://genius.com/Tyler-the-creator-911-mr-lonely-lyrics',
#  'https://genius.com/Tyler-the-creator-who-dat-boy-lyrics',
#  'https://genius.com/Tyler-the-creator-tron-cat-lyrics',
#  'https://genius.com/Tyler-the-creator-tamale-lyrics',
#  'https://genius.com/Immortal-technique-dance-with-the-devil-lyrics',
#  'https://genius.com/Immortal-technique-you-never-know-lyrics',
#  'https://genius.com/Immortal-technique-the-point-of-no-return-lyrics',
#  'https://genius.com/Immortal-technique-obnoxious-lyrics',
#  'https://genius.com/Immortal-technique-the-4th-branch-lyrics',
#  'https://genius.com/Immortal-technique-the-cause-of-death-lyrics',
#  'https://genius.com/Immortal-technique-leaving-the-past-lyrics',
#  'https://genius.com/Immortal-technique-the-poverty-of-philosophy-lyrics',
#  'https://genius.com/Immortal-technique-industrial-revolution-lyrics',
#  'https://genius.com/Immortal-technique-rich-mans-world-1-lyrics',
#  'https://genius.com/Kendrick-lamar-humble-lyrics',
#  'https://genius.com/Kendrick-lamar-maad-city-lyrics',
#  'https://genius.com/Kendrick-lamar-swimming-pools-drank-lyrics',
#  'https://genius.com/Kendrick-lamar-dna-lyrics',
#  'https://genius.com/Kendrick-lamar-money-trees-lyrics',
#  'https://genius.com/Kendrick-lamar-xxx-lyrics',
#  'https://genius.com/Kendrick-lamar-bitch-dont-kill-my-vibe-lyrics',
#  'https://genius.com/Kendrick-lamar-king-kunta-lyrics',
#  'https://genius.com/Kendrick-lamar-love-lyrics',
#  'https://genius.com/Kendrick-lamar-backseat-freestyle-lyrics']

# %%
#Grab title of each song

titles = []

for e in songList:
    page = requests.get(e)
    soup = BeautifulSoup(page.content, "html.parser")
    
    titles.append(soup.find("h1").text)

# %%
#pickle titles for later use
#with open('raplyricstitle.txt','wb') as file1:
#    pickle.dump(titles, file1)

# %%
#Grab artist for each song

import re

artists = []

for e in songList:
    page = requests.get(e)
    soup = BeautifulSoup(page.content, "html.parser")
    
    artists.append(soup.find(class_="Link-h3isu4-0 hwdSYP SongHeaderVariantdesktop__Artist-sc-12tszai-11 ayFeg").text)

# %%
artists
# Out:
# ['Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'A Tribe Called Quest',
#  'A Tribe Called Quest',
#  'A Tribe Called Quest',
#  'A Tribe Called Quest',
#  'A Tribe Called Quest',
#  'A Tribe Called Quest',
#  'A Tribe Called Quest',
#  'A Tribe Called Quest',
#  'A Tribe Called Quest',
#  'A Tribe Called Quest',
#  'N.W.A',
#  'N.W.A',
#  'N.W.A',
#  'N.W.A',
#  'N.W.A',
#  'N.W.A',
#  'N.W.A',
#  'N.W.A',
#  'N.W.A',
#  'N.W.A',
#  'OutKast',
#  'OutKast',
#  'OutKast',
#  'OutKast',
#  'OutKast',
#  'OutKast',
#  'OutKast',
#  'OutKast',
#  'OutKast',
#  'OutKast',
#  'Nas',
#  'Nas',
#  'Nas',
#  'Nas',
#  'Nas',
#  'Nas',
#  'Nas',
#  'Nas',
#  'Nas',
#  'Nas',
#  'The Notorious B.I.G.',
#  'The Notorious B.I.G.',
#  'The Notorious B.I.G.',
#  'The Notorious B.I.G.',
#  'The Notorious B.I.G.',
#  'The Notorious B.I.G.',
#  'The Notorious B.I.G.',
#  'The Notorious B.I.G.',
#  'The Notorious B.I.G.',
#  'The Notorious B.I.G.',
#  '2Pac',
#  '2Pac',
#  '2Pac',
#  '2Pac',
#  '2Pac',
#  '2Pac',
#  '2Pac',
#  '2Pac',
#  '2Pac',
#  '2Pac',
#  'Logic',
#  'Logic',
#  'Logic',
#  'Logic',
#  'Logic',
#  'Logic',
#  'Logic',
#  'Logic',
#  'Logic',
#  'Logic',
#  'JAY-Z & Kanye West',
#  'JAY-Z & Kanye West',
#  'JAY-Z & Kanye West',
#  'JAY-Z & Kanye West',
#  'JAY-Z & Kanye West',
#  'JAY-Z & Kanye West',
#  'JAY-Z & Kanye West',
#  'JAY-Z & Kanye West',
#  'JAY-Z & Kanye West',
#  'JAY-Z & Kanye West',
#  'Tyler, The Creator',
#  'Tyler, The Creator',
#  'Tyler, The Creator',
#  'Tyler, The Creator',
#  'Tyler, The Creator',
#  'Tyler, The Creator',
#  'Tyler, The Creator',
#  'Tyler, The Creator',
#  'Tyler, The Creator',
#  'Tyler, The Creator',
#  'Immortal Technique',
#  'Immortal Technique',
#  'Immortal Technique',
#  'Immortal Technique',
#  'Immortal Technique',
#  'Immortal Technique',
#  'Immortal Technique',
#  'Immortal Technique',
#  'Immortal Technique',
#  'Immortal Technique',
#  'Kendrick Lamar',
#  'Kendrick Lamar',
#  'Kendrick Lamar',
#  'Kendrick Lamar',
#  'Kendrick Lamar',
#  'Kendrick Lamar',
#  'Kendrick Lamar',
#  'Kendrick Lamar',
#  'Kendrick Lamar',
#  'Kendrick Lamar']

# %%
#pickle for later use
#with open('raplyricsartists.txt','wb') as file2:
#    pickle.dump(artists, file2)

# %%
#Grab the album for the track

albumtest = []

for e in songList:
    page = requests.get(e)
    soup = BeautifulSoup(page.content, "html.parser")
    
    albumtest.append(soup.find(class_="Link-h3isu4-0 gHBbjJ").text)

# %%
album = []

for e in albumtest:
    albumstring = e.replace('\xa0', '')
    album.append(albumstring)

# %%
album
# Out:
# ['Enter the Wu-Tang (36 Chambers)',
#  'Protect Ya Neck – Single',
#  'Enter the Wu-Tang (36 Chambers)',
#  'Protect Ya Neck – Single',
#  'Wu-Tang Forever',
#  'Enter the Wu-Tang (36 Chambers)',
#  'Enter the Wu-Tang (36 Chambers)',
#  'Enter the Wu-Tang (36 Chambers)',
#  'Enter the Wu-Tang (36 Chambers)',
#  'Enter the Wu-Tang (36 Chambers)',
#  'We got it from Here... Thank You 4 Your service',
#  'Midnight Marauders',
#  'The Low End Theory',
#  'People’s Instinctive Travels and the Paths of Rhythm',
#  'The Low End Theory',
#  'The Low End Theory',
#  'People’s Instinctive Travels and the Paths of Rhythm',
#  'The Low End Theory',
#  'We got it from Here... Thank You 4 Your service',
#  'Midnight Marauders',
#  'Straight Outta Compton',
#  'Straight Outta Compton',
#  'Straight Outta Compton',
#  'Straight Outta Compton',
#  'N.W.A. and the Posse',
#  'N.W.A. Greatest Hits',
#  'N.W.A. and the Posse',
#  '100 Miles and Runnin’',
#  'Efil4zaggin',
#  'N.W.A. Greatest Hits',
#  'Speakerboxxx / The Love Below',
#  'Stankonia',
#  'Speakerboxxx / The Love Below',
#  'Aquemini',
#  'ATLiens',
#  'Stankonia',
#  'Stankonia',
#  'Aquemini',
#  'ATLiens',
#  'Aquemini',
#  'Illmatic',
#  'Stillmatic',
#  'Illmatic',
#  'Illmatic',
#  'It Was Written',
#  'Illmatic',
#  'Illmatic',
#  'It Was Written',
#  'Illmatic',
#  'I Am...',
#  'Ready to Die',
#  'Ready to Die',
#  'Ready to Die',
#  'Life After Death',
#  'Life After Death',
#  'Life After Death',
#  'Ready to Die',
#  'Life After Death',
#  'Ready to Die',
#  'Ready to Die',
#  'Greatest Hits',
#  'Greatest Hits',
#  'Strictly 4 My N.I.G.G.A.Z...',
#  'The Don Killuminati: The 7 Day Theory',
#  'Me Against The World',
#  'Greatest Hits',
#  'All Eyez On Me',
#  'All Eyez On Me',
#  'All Eyez On Me',
#  'All Eyez On Me',
#  'Everybody',
#  'Confessions of a Dangerous Mind',
#  'Under Pressure (Deluxe Version)',
#  'Bobby Tarantino II',
#  'Everybody',
#  'Under Pressure (Deluxe Version)',
#  'Under Pressure (Deluxe Version)',
#  'Everybody',
#  'Under Pressure (Deluxe Version)',
#  'The Incredible True Story',
#  'Watch the Throne',
#  'Watch the Throne',
#  'Watch the Throne',
#  'Watch the Throne',
#  'Watch the Throne',
#  'Watch the Throne',
#  'Watch the Throne',
#  'Watch the Throne',
#  'Watch the Throne',
#  'Watch the Throne',
#  'Goblin',
#  'IGOR',
#  'Flower Boy',
#  'Wolf',
#  'Goblin',
#  'IGOR',
#  'Flower Boy',
#  'Flower Boy',
#  'Goblin',
#  'Wolf',
#  'Revolutionary Vol. 1',
#  'Revolutionary Vol. 2',
#  'Revolutionary Vol. 2',
#  'Revolutionary Vol. 2',
#  'Revolutionary Vol. 2',
#  'Revolutionary Vol. 2',
#  'Revolutionary Vol. 2',
#  'Revolutionary Vol. 1',
#  'Revolutionary Vol. 2',
#  'The Martyr',
#  'DAMN.',
#  'good kid, m.A.A.d city (Deluxe Version)',
#  'good kid, m.A.A.d city (Deluxe Version)',
#  'DAMN.',
#  'good kid, m.A.A.d city (Deluxe Version)',
#  'DAMN.',
#  'good kid, m.A.A.d city (Deluxe Version)',
#  'To Pimp a Butterfly',
#  'DAMN.',
#  'good kid, m.A.A.d city (Deluxe Version)']

# %%
#pickle for later use
#with open('raplyricsalbum.txt','wb') as file3:
#    pickle.dump(album, file3)

# %%
#Album/Track release year

albumyear = []

for e in songList:
    page = requests.get(e)
    soup = BeautifulSoup(page.content, "html.parser")
    
    year = soup.find('div', class_="SongHeaderVariantdesktop__Column-sc-12tszai-1 SongHeaderVariantdesktop__Right-sc-12tszai-4 jryaLr").get_text()
    
    yearint = re.findall('\d+', year)
    
    albumyear.append(yearint[1])

# %%
albumreleaseyear = []

for e in albumyear:
    newyear = int(e)
    albumreleaseyear.append(newyear)

# %%
albumreleaseyear
# Out:
# [1994, 1992, 1993, 1993, 1997, 1993, 1993, 1993, 1993, 1993, 2016, 1993, 1992, 1990, 1991, 1991, 1990, 1991, 2016, 1993, 1988, 1988, 1988, 1988, 1987, 1999, 1987, 1990, 1991, 1990, 2003, 2000, 2003, 1998, 1996, 2000, 2001, 1998, 1996, 1998, 1994, 2001, 1994, 1994, 1997, 1994, 1994, 1996, 1994, 1999, 1994, 1995, 1994, 1997, 1997, 1997, 1994, 1997, 1994, 1994, 1996, 1998, 1993, 1997, 1995, 1995, 1996, 1996, 1996, 1996, 2017, 2019, 2014, 2018, 2017, 2014, 2014, 2017, 2014, 2015, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2019, 2017, 2013, 2011, 2019, 2017, 2017, 2011, 2013, 2001, 2003, 2003, 2003, 2003, 2003, 2003, 2001, 2003, 2011, 2017, 2012, 2012, 2017, 2012, 2017, 2012, 2015, 2017, 2012]

# %%
#fix album release years 
albumreleaseyear[29] = 1990
albumreleaseyear[30] = 2003
albumreleaseyear[32] = 2003
albumreleaseyear[53] = 1997
albumreleaseyear[59] = 1994
albumreleaseyear[70] = 2017
albumreleaseyear[72] = 2014
albumreleaseyear[73] = 2018
albumreleaseyear[74] = 2017
albumreleaseyear[75] = 2014
albumreleaseyear[76] = 2014
albumreleaseyear[77] = 2017
albumreleaseyear[80] = 2011
albumreleaseyear[81] = 2011
albumreleaseyear[84] = 2011
albumreleaseyear[86] = 2011
albumreleaseyear[89] = 2011
albumreleaseyear[100] = 2001
albumreleaseyear[111] = 2012
albumreleaseyear[115] = 2017
albumreleaseyear[118] = 2017

# %%
#pickle for later use
#with open('raplyricsreleaseyear.txt','wb') as file4:
#    pickle.dump(albumreleaseyear, file4)

# %%
#Grab lyrics for all songs

lyricslist = []

for e in songList:
    page = requests.get(e)
    soup = BeautifulSoup(page.content, "html.parser")
    
    lyricspersong = soup.find("div", id='lyrics-root').get_text(', ')
    
    lyricslist.append(lyricspersong)

# %%
#pickle for later use
#with open('raplyrics.txt','wb') as file5:
#    pickle.dump(lyricslist, file5)

# %%
artistdictionary = {}

# %%
for e in artistnames:
    artistdictionary[e] = None

# %%
artistdictionary
# Out:
# {'Wu-Tang Clan': None, 'A Tribe Called Quest': None, 'N.W.A.': None, 'Outkast': None, 'Nas': None, 'The Notorious B.I.G.': None, '2pac': None, 'Logic': None, 'Jay-z and Kanye West': None, 'Tyler the Creator': None, 'Immortal Technique': None, 'Kendrick Lamar': None}

# %%
#combine lyrics for each artist
artistdictionary.update({'Wu-Tang Clan': lyricslist[:9]})
artistdictionary.update({'A Tribe Called Quest': lyricslist[10:19]})
artistdictionary.update({'N.W.A.': lyricslist[20:29]})
artistdictionary.update({'Outkast': lyricslist[30:39]})
artistdictionary.update({'Nas': lyricslist[40:49]})
artistdictionary.update({'The Notorious B.I.G.': lyricslist[50:59]})
artistdictionary.update({'2pac': lyricslist[60:69]})
artistdictionary.update({'Logic': lyricslist[70:79]})
artistdictionary.update({'Jay-z and Kanye West': lyricslist[80:89]})
artistdictionary.update({'Tyler the Creator': lyricslist[90:99]})
artistdictionary.update({'Immortal Technique': lyricslist[100:109]})
artistdictionary.update({'Kendrick Lamar': lyricslist[110:119]})

# %%
#pickle for later use
#with open('raplyricscombined.txt','wb') as file6:
#    pickle.dump(artistdictionary, file6)

# %%
#combine all the text into one, rather than separate elements 
def combine_text(list_of_text):
    combined_text = ' '.join(list_of_text)
    return combined_text

# %%
data_combined = {key: [combine_text(value)] for (key, value) in artistdictionary.items()}

# %%
#finally, put this all in its own dataframe
import pandas as pd

data_df = pd.DataFrame.from_dict(data_combined).transpose()
data_df.columns = ['Lyrics']
data_df = data_df.sort_index()

# %%
data_df
# Out:
#                                                                  Lyrics
# 2pac                  Hit ’Em Up Lyrics, [Intro: 2Pac], Sucka-ass, I...
# A Tribe Called Quest  We the People.... Lyrics, [Verse 1: Q-Tip], We...
# Immortal Technique    Dance with the Devil Lyrics, [Part I: Dance wi...
# Jay-z and Kanye West  Niggas in Paris Lyrics, [Intro], We're gonna s...
# Kendrick Lamar        HUMBLE. Lyrics, [Intro], Nobody pray for me, I...
# Logic                 1-800-273-8255 Lyrics, [Pre-Chorus: Logic], I'...
# N.W.A.                Fuck tha Police Lyrics, [Produced by Dr. Dre &...
# Nas                   N.Y. State of Mind Lyrics, [Produced by DJ Pre...
# Outkast               Hey Ya! Lyrics, [Intro: André 3000], One, two,...
# The Notorious B.I.G.  Juicy Lyrics, [Intro: The Notorious B.I.G.], (...
# Tyler the Creator     Yonkers Lyrics, [Intro], Uh, Wolf Haley, Golf ...
# Wu-Tang Clan          C.R.E.A.M. Lyrics, [Produced by RZA], [Intro: ...

# %% [markdown]
# # DATA CLEANING

# %%
#Clean up round 1
import string

def clean_up_1(text):
    text = text.lower()
#    text = re.sub('\[.*-?\]','',text)
    text = re.sub('[%s]' % re.escape(string.punctuation),'',text)
    text = re.sub('\w*\d\w*','',text)
    text = re.sub('[''""...-]','',text)
    text = re.sub('\n','',text)
    return text
    
round_1 = lambda x: clean_up_1(x)

# %%
data_clean = pd.DataFrame(data_df.Lyrics.apply(round_1))

# %%
pd.set_option('max_colwidth',150)
data_clean
# Out:
# Outkast               hey ya   andré  one two three uh   andré  my baby dont mess around because she loves me so and this i know for sure uh but does she really wanna b...
# The Notorious B.I.G.  juicy   the notorious big fuck all you hoes get a grip motherfucker yeah this album is dedicated to all the teachers that told me id never amount ...
# Tyler the Creator     yonkers   uh wolf haley golf wang go   im a fuckin walkin paradox no im not threesomes with a fuckin triceratops reptar rappin as im mockin deaf r...
# Wu-Tang Clan          cream   rza  raekwon   method man  what that nigga want god word up look out for the cops though  wutang five finger shit fam  cash rules word up ...

# %%
#data_df is the corpus and data_clean is the data we will put into the document-term matrix. Pickle both
#data_df.to_pickle('corpus.pkl')
#data_clean.to_pickle('data_clean.pkl')

# %% [markdown]
# # COUNT VECTORIZER

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(data_clean['Lyrics'])
data_dtm = pd.DataFrame(data_cv.toarray(),columns=cv.get_feature_names_out())
data_dtm.index = data_clean.index

# %%
data_dtm
# Out:
#                       aa  aaaahah  aaaahhh  aah  aames  aap  abbot  abel  \
# 2pac                   0        0        0    0      0    0      0     0
# A Tribe Called Quest   0        0        0    0      0    0      0     0
# Immortal Technique     1        0        0    0      0    0      0     0
# Jay-z and Kanye West   0        0        0    0      0    0      0     0
# Kendrick Lamar         0        0        0    0      0    0      0     0
# Logic                  1        0        0    0      1    0      0     0
# N.W.A.                 0        0        0    0      0    0      0     0
# Nas                    0        0        0    0      0    0      0     0
# Outkast                0        0        0    0      0    0      0     0
# The Notorious B.I.G.   0        0        0    0      0    0      0     0
# Tyler the Creator      0        0        1    0      0    5      0     0
# Wu-Tang Clan           0        1        0    1      0    0      1     1
#
#                       able  abolished  ...  zero  zigzagzig  zipper  zone  \
# 2pac                     0          0  ...     0          0       0     1
# A Tribe Called Quest     0          0  ...     0          0       0     1
# Immortal Technique       0          0  ...     1          0       0     1
# Jay-z and Kanye West     0          0  ...     4          0       0    10
# Kendrick Lamar           0          0  ...     0          0       0     0
# Logic                    1          1  ...     0          0       0     1
# N.W.A.                   0          0  ...     0          0       0     0
# Nas                      0          0  ...     0          0       0     0
# Outkast                  0          0  ...     0          0       1     2
# The Notorious B.I.G.     0          0  ...     0          0       0     0
# Tyler the Creator        0          0  ...     0          0       0     0
# Wu-Tang Clan             0          0  ...     0          1       0     2
#
#                       zoo  zoom  zs  zulu  zyklonb  zé
# 2pac                    0     0   0     0        0   0
# A Tribe Called Quest    0     0   1     3        0   0
# Immortal Technique      1     0   0     0        1   0
# Jay-z and Kanye West    0     0   0     0        0   0
# Kendrick Lamar          0     0   0     0        0   0
# Logic                   0     0   0     0        0   0
# N.W.A.                  0     0   0     0        0   0
# Nas                     0     0   0     0        0   1
# Outkast                 0     0   0     0        0   0
# The Notorious B.I.G.    0     0   0     0        0   0
# Tyler the Creator       0     0   0     0        0   0
# Wu-Tang Clan            1     1   0     1        0   0
#
# [12 rows x 8118 columns]

# %%
#pickle for later use
data_dtm.to_pickle('dtm.pkl')

# %% [markdown]
# # CLEAN DATAFRAME

# %%
zipped = list(zip(titles, artists, album, albumreleaseyear, lyricslist))

# %%
import pandas as pd

df = pd.DataFrame(zipped, columns=['Title','Artist','Album','Release Year','Lyrics'])

# %%
df.index += 1

# %%
df
# Out:
#                          Title          Artist  \
# 1                   C.R.E.A.M.    Wu-Tang Clan
# 2              Protect Ya Neck    Wu-Tang Clan
# 3    Da Mystery of Chessboxin’    Wu-Tang Clan
# 4                   Method Man    Wu-Tang Clan
# 5                      Triumph    Wu-Tang Clan
# ..                         ...             ...
# 116                       XXX.  Kendrick Lamar
# 117  Bitch, Don’t Kill My Vibe  Kendrick Lamar
# 118                 King Kunta  Kendrick Lamar
# 119                      LOVE.  Kendrick Lamar
# 120         Backseat Freestyle  Kendrick Lamar
#
#                                        Album  Release Year  \
# 1            Enter the Wu-Tang (36 Chambers)          1994
# 2                   Protect Ya Neck – Single          1992
# 3            Enter the Wu-Tang (36 Chambers)          1993
# 4                   Protect Ya Neck – Single          1993
# 5                            Wu-Tang Forever          1997
# ..                                       ...           ...
# 116                                    DAMN.          2017
# 117  good kid, m.A.A.d city (Deluxe Version)          2012
# 118                      To Pimp a Butterfly          2015
# 119                                    DAMN.          2017
# 120  good kid, m.A.A.d city (Deluxe Version)          2012
#
#                                                                                                                                                     Lyrics
# 1    C.R.E.A.M. Lyrics, [Produced by RZA], [Intro: Raekwon & , Method Man, ], What that nigga want, God?, Word up, look out for the cops though (, Wu-T...
# 2    Protect Ya Neck Lyrics, [Skit], Caller: "So whassup, man?", DJ: "Coolin', man.", C: "Chillin' chilin'? Yo, you know I had to call, you know why ri...
# 3    Da Mystery of Chessboxin’ Lyrics, [Intro: "Shaolin vs. Wu-Tang" + , "Five Deadly Venoms", ], A game of chess is like a swordfight:, You must think...
# 4    Method Man Lyrics, [Skit: Method Man & , Raekwon, ], Yeah, torture, motherfucker, what?, Torture, nigga, what?, What? I'll fuckin', I'll fuckin' t...
# 5    Triumph Lyrics, [Intro: Ol' Dirty Bastard], What? Y'all thought y'all wasn't gonna see me?, I'm the Osiris of this shit, Wu-Tang is here forever, ...
# ..                                                                                                                                                     ...
# 116  XXX. Lyrics, [Intro: Bēkon & , Kid Capri, ], America, God bless you if it's good to ya, America, please take my hand, Can you help me underst—, Ne...
# 117  Bitch, Don’t Kill My Vibe Lyrics, [Produced by Sounwave], [Chorus: Kendrick Lamar], I am a sinner who's probably gonna sin again, Lord, forgive me...
# 118  King Kunta Lyrics, [Produced by Sounwave; Additional production by Terrace Martin], [Intro: Kendrick Lamar], I got a bone to pick, I don't want yo...
# 119  LOVE. Lyrics, [Intro: Kendrick Lamar], Damn, love or lust, Damn, all of us, [Chorus: Zacari & , Kendrick Lamar, ], Give me a run for my money, The...
# 120  Backseat Freestyle Lyrics, [Produced by Hit-Boy], [Intro], Uh, Martin had a dream, Martin had a dream, Kendrick have a dream, [Chorus], All my lif...
#
# [120 rows x 5 columns]

# %%
#Pickle df for later use
df.to_pickle('clean-df.pkl')
